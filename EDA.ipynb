# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
compas = pd.read_csv('/gdrive/MyDrive/DSCI 531/ProPublica COMPAS Data/compas_20250328_165700.csv')
prisonhistory = pd.read_csv('/gdrive/MyDrive/DSCI 531/ProPublica COMPAS Data/prisonhistory_20250328_164400.csv')

# %%
under18 = prisonhistory.copy()
under18 = under18[under18['minors'] < 18]
under18names = under18.copy()
under18names = under18names[['id', 'first', 'last']]

# %%
under18names
# Out:
#         id    first     last
# 15     518    barry     hope
# 32    4837   sharon  johnson
# 39    3315    james    brown
# 40    2747  charles    dixon
# 42     252    barry   harden
# ...    ...      ...      ...
# 3210  2850   willis   barnes
# 3288  4637    paret    baker
# 3453  3818   carlos   garcia
# 3535   951  bernard  augusme
# 4359  3892    malik   mccrea
#
# [112 rows x 3 columns]

# %%
minors_full_variables = pd.merge(under18names, people, on= ['first', 'last'], how='left')

# %%
minors_full_variables
# Out:
#      id_x    first     last  id_y             name     sex              race  \
# 0     518    barry     hope  5303       barry hope    Male  African-American
# 1    4837   sharon  johnson  4725   sharon johnson  Female  African-American
# 2    3315    james    brown  3006      james brown    Male  African-American
# 3    3315    james    brown  6942      james brown    Male  African-American
# 4    3315    james    brown  8470      james brown    Male  African-American
# ..    ...      ...      ...   ...              ...     ...               ...
# 110  2850   willis   barnes  2134    willis barnes    Male  African-American
# 111  4637    paret    baker  3116      paret baker    Male  African-American
# 112  3818   carlos   garcia  9437    carlos garcia    Male          Hispanic
# 113   951  bernard  augusme   542  bernard augusme    Male  African-American
# 114  3892    malik   mccrea   391     malik mccrea    Male  African-American
#
# ...

# %%
minors_race_list = minors_full_variables['race'].tolist()
print(minors_race_list)
black = 0
indigenous = 0
white = 0
hispanic = 0
for race in minors_race_list:
  print(race)
  if race == 'African-American':
    black += 1
  if race == 'Caucasian':
    white += 1
  if race == 'Native American':
    indigenous += 1
  if race == 'Hispanic':
    hispanic += 1
# Out:
# ['African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'Native American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'Caucasian', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'Caucasian', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'African-American', 'Caucasian', 'African-American', 'African-American', 'Caucasian', 'African-American', 'African-American', 'African-American', 'Afric
# ...

# %%
97+9+2+7
97/115
# Out:
# 0.8434782608695652

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))
plt.title('Racial Distribution of Offenders in the Broward County COMPAS Dataset')
plt.xlabel('Offender Race')
plt.ylabel('Count')
plt.hist(people['race'])
# Out:
# (array([ 661.,    0., 4085.,    0., 5813.,    0., 1100.,    0.,   58.,
#           40.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,4))
plt.title('Racial Distribution of Confirmed Juvenile Offenders in the Broward County COMPAS Dataset')
plt.xlabel('Offender Race')
plt.ylabel('Count')
plt.hist(minors_full_variables['race'])
# Out:
# (array([97.,  0.,  0.,  2.,  0.,  0.,  9.,  0.,  0.,  7.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
file_path = '/gdrive/MyDrive/DSCI 531/ArkansasJuv/08973-0001-Data.dta'

df = pd.read_stata(file_path)

# %%
# 281: % white male, % white female, % black male, % black female (all juveniles)
#facilities where white male residents outnumber black male residents
exploratorydf = df[['V281', 'V282', 'V285', 'V286', 'V40']]
exploratorydfwb = exploratorydf[exploratorydf['V281']  > exploratorydf['V285']]
exploratorydfwb
# Out:
#       V281  V282  V285  V286               V40
# 0       26     7    23     3            Medium
# 5        6     0     3     0           Minimum
# 7        7     0     4     0           Minimum
# 8        6     0     4     0           Minimum
# 10      22     5     8     4  Maximum (Strict)
# ...    ...   ...   ...   ...               ...
# 1099     4     5     1     0           Minimum
# 1100     3     2     0     0            Medium
# 1102     1     0     0     0              None
# 1104     7     5     0     0           Minimum
# 1105    73     0     2     0           Minimum
#
# [623 rows x 5 columns]

# %%
#facilities where black male residents outnumber white male residents
exploratorydf = df[['V281', 'V282', 'V285', 'V286', 'V40']]
exploratorydfbw = exploratorydf[exploratorydf['V281']  < exploratorydf['V285']]
exploratorydfbw
# Out:
#       V281  V282  V285  V286               V40
# 1       50     0    87     0            Medium
# 2       59     0    60     0            Medium
# 4       32    29    44    38            Medium
# 6        4     0     7     0           Minimum
# 13       7     3    11     5  Maximum (Strict)
# ...    ...   ...   ...   ...               ...
# 1047     1     1     3     2           Minimum
# 1057     2     6     4     1              None
# 1096    70     0   175     0  Maximum (Strict)
# 1101    22     1    67     4            Medium
# 1103     5     2     6     1  Maximum (Strict)
#
# [324 rows x 5 columns]

# %%
import seaborn as sns

# %%
securityb = sns.catplot(x="V285", y="V40", data = exploratorydfbw, kind="box")
securityb.fig.set_size_inches(9,6)
plt.title('Black Male Youth Population by Security Level for Majority Black Facilities')
plt.xlabel('Black Male Youth Population')
plt.ylabel('Facility Security Level')
plt.show()

# %%
securityw = sns.catplot(x="V281", y="V40", data = exploratorydfwb, kind="box")
securityw.fig.set_size_inches(9,6)
plt.title('White Male Youth Population by Security Level for Majority White Facilities')
plt.xlabel('White Male Youth Population')
plt.ylabel('Facility Security Level')
plt.show()
